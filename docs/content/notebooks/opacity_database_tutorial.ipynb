# %% [markdown]
# # Cross Section Calculation Pipeline to an Opacity Database

# %% [markdown]
# This tutorial extends the [one on computing cross sections at multiple pressures and temperatures](https://excalibur-xsec.readthedocs.io/en/latest/content/notebooks/cross_section_grid.html) by using a much larger factor space. Here we show how to make a full cross section grid using Excalcibur, and use that grid to start making an opacity database.
#
# We'll use AlO as an example, since this is a small line list (~ 5 million transitions) that can easily run on a laptop. We recommend running Excalibur only on a laptop for line lists that are less than ~100 million transitions. For larger line lists, or very large grids, we recommend running on a cluster, as shown in [our other tutorial](https://excalibur-xsec.readthedocs.io/en/latest/content/notebooks/slurm_tutorial.html).

# %% [markdown]
# ## Download ExoMol Line List

# %%
from Excalibur.core import summon

species = 'AlO'

database = 'ExoMol'
linelist = 'ATP'         # Linelist name

broadening = 'H2-He'     # Background gas broadening

nu_min = 200
nu_max = 35000

input_directory = './input/'

# %%
# Download line list
summon(database=database, species = species, linelist = linelist)
# Out:
#  ***** Downloading requested data from ExoMol. You have chosen the following parameters: *****
#
# Molecule: AlO
# Isotopologue: 27Al-16O
# Line List: ATP
#
# Starting by downloading the .broad, .pf, and .states files...
# Fetched the broadening coefficients, partition functions, and energy levels.
# Now downloading the ATP line list...
#
# Downloading .trans file 1 of 1
# 100%|██████████| 32.6M/32.6M [00:04<00:00, 6.63MiB/s]
# Converting this .trans file to HDF to save storage space...
# This file took 1.3 seconds to reformat to HDF.
#
# Line list ready.

# %% [markdown]
# ## Calculate A Single Cross Section

# %% [markdown]
# First, let's calculate the cross section of AlO for a single pressure-temperature point to get a handle on the runtime. We'll choose 10 bar and 1000 K.

# %%
import numpy as np
from Excalibur.core import compute_cross_section

P = [1.0]
log_P = [0.0]
T = [1000.0]

compute_cross_section(database = database, species = species, linelist = linelist,
                      pressure = P, temperature = T, S_cut = 0.0,                      # No intensity cutoff (S_cut)
                      input_dir = input_directory,
                      nu_out_min = nu_min, nu_out_max = nu_max, dnu_out = 0.01,
                      broad_type = broadening,
                      verbose = True, N_cores = 4)    # Runing on 4 cores
# Out:
# Beginning cross-section computations...
# Loading ExoMol format
# Loading partition function
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.5303670409994083 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 1000.0 K
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 19.736017598996114 s
# Calculation complete!
# Completed 4943804 transitions in 19.736656503999257 s
#
# Total runtime: 24.09071022900025 s

# %% [markdown]
# We see that AlO only takes about 20 s for a single (P,T) point, so we can easily compute a cross section for a grid of pressures and temperatures.
#
# Let's plot the cross section.

# %%
from Excalibur.misc import read_cross_section_file, cross_section_collection
from Excalibur.plot import plot_cross_section

'''Read in the cross section we just computed'''

# Read in cross section
nu, sigma = read_cross_section_file(species = species, database = database, ionization_state = 1,
                                    filename = species + '_T' + str(T[0]) + 
                                    'K_log_P' + str(log_P[0]) + '_' + broadening + '_sigma.txt')

cross_sections = []

# Add first cross section to collection
cross_sections = cross_section_collection(new_x = nu, new_y = sigma, collection = cross_sections)

plot_cross_section(collection = cross_sections, labels = [species + ' (1000 K, 1 bar)'], 
                    filename = species, y_min = 1e-30, x_max = 10, save_fig = False)
# Out:
# Plotting complete.

# %% [markdown]
# Looking good! Now let's iterate over pressures and temperatures to generate a full AlO cross section.

# %% [markdown]
# #### Full cross section calculation

# %%
from Excalibur.core import compute_cross_section

P = [1.0e-6, 1.0e-5, 1.0e-4, 1.0e-3, 1.0e-2, 1.0e-1, 1.0e0, 1.0e1, 1.0e2]    # Pressure (bar)
log_P = [-6.0, -5.0, -4.0, -3.0, -2.0, -1.0, 0.0, 1.0, 2.0]                  # log10 pressure
T = [100.0, 200.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0,                 # Temperature (K)
     900.0, 1000.0, 1200.0, 1400.0, 1600.0, 1800.0, 2000.0,
     2500.0, 3000.0, 3500.0]

compute_cross_section(database = database, species = species, linelist = linelist,
                      pressure = P, temperature = T, S_cut = 0.0,
                      input_dir = input_directory,
                      nu_out_min = nu_min, nu_out_max = nu_max, dnu_out = 0.01,
                      broad_type = broadening,
                      verbose = True, N_cores = 4)
# Out:
# Beginning cross-section computations...
# Loading ExoMol format
# Loading partition function
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.07099297805689275 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 100.0 K   [1 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 3.543925949023105 s
# Calculation complete!
# Completed 4943804 transitions in 3.5445582550019026 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06722104700747877 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 200.0 K   [2 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 4.86141890892759 s
# Calculation complete!
# Completed 4943804 transitions in 4.862033067038283 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06620053004007787 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 300.0 K   [3 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.664704155991785 s
# Calculation complete!
# Completed 4943804 transitions in 5.665388689027168 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.061048418981954455 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 400.0 K   [4 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.797482291935012 s
# Calculation complete!
# Completed 4943804 transitions in 6.7981158890761435 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06315579800866544 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 500.0 K   [5 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.340706478105858 s
# Calculation complete!
# Completed 4943804 transitions in 7.34130152198486 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06304824200924486 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 600.0 K   [6 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.007387725054286 s
# Calculation complete!
# Completed 4943804 transitions in 8.008005004026927 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06660251598805189 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 700.0 K   [7 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.071052788989618 s
# Calculation complete!
# Completed 4943804 transitions in 10.071608812082559 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06462274107616395 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 800.0 K   [8 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.124799716984853 s
# Calculation complete!
# Completed 4943804 transitions in 10.125420372001827 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06384072091896087 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 900.0 K   [9 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.28065726091154 s
# Calculation complete!
# Completed 4943804 transitions in 10.281342320959084 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06794098496902734 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 1000.0 K   [10 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.524726260919124 s
# Calculation complete!
# Completed 4943804 transitions in 10.525334415957332 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0614045049296692 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 1200.0 K   [11 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.132664471049793 s
# Calculation complete!
# Completed 4943804 transitions in 11.133364323992282 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06130653899163008 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 1400.0 K   [12 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.681266417028382 s
# Calculation complete!
# Completed 4943804 transitions in 11.681948950979859 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06095478206407279 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 1600.0 K   [13 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.780997483991086 s
# Calculation complete!
# Completed 4943804 transitions in 11.781741442973725 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06629890901967883 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 1800.0 K   [14 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.349284408031963 s
# Calculation complete!
# Completed 4943804 transitions in 12.349877010914497 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06724344904068857 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 2000.0 K   [15 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.336358548956923 s
# Calculation complete!
# Completed 4943804 transitions in 12.336961879045703 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06544686492998153 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 2500.0 K   [16 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.657765416894108 s
# Calculation complete!
# Completed 4943804 transitions in 12.658438395010307 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06569516099989414 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 3000.0 K   [17 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.944711379008368 s
# Calculation complete!
# Completed 4943804 transitions in 11.945341299986467 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06586328498087823 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-06 bar, T = 3500.0 K   [18 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.462639134959318 s
# Calculation complete!
# Completed 4943804 transitions in 11.4632812240161 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06564523105043918 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 100.0 K   [19 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 3.4756674639647827 s
# Calculation complete!
# Completed 4943804 transitions in 3.476292524021119 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06558194698300213 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 200.0 K   [20 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.253582907025702 s
# Calculation complete!
# Completed 4943804 transitions in 5.254181231022812 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06707533809822053 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 300.0 K   [21 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.720664910972118 s
# Calculation complete!
# Completed 4943804 transitions in 5.721283839084208 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0652835430810228 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 400.0 K   [22 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.710428256075829 s
# Calculation complete!
# Completed 4943804 transitions in 6.710896854987368 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06611964292824268 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 500.0 K   [23 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.525822945986874 s
# Calculation complete!
# Completed 4943804 transitions in 7.526427980046719 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06480449391528964 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 600.0 K   [24 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.828809364931658 s
# Calculation complete!
# Completed 4943804 transitions in 8.829483072040603 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06214585795532912 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 700.0 K   [25 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.87169995997101 s
# Calculation complete!
# Completed 4943804 transitions in 8.872398542007431 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06096252193674445 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 800.0 K   [26 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.179169593960978 s
# Calculation complete!
# Completed 4943804 transitions in 9.179757303907536 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.061755790025927126 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 900.0 K   [27 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.959468737011775 s
# Calculation complete!
# Completed 4943804 transitions in 9.96008876990527 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06134822906460613 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 1000.0 K   [28 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.973099328926764 s
# Calculation complete!
# Completed 4943804 transitions in 9.973704171017744 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.061170242028310895 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 1200.0 K   [29 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.43104981794022 s
# Calculation complete!
# Completed 4943804 transitions in 10.43165001203306 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06140852998942137 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 1400.0 K   [30 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.134845866938122 s
# Calculation complete!
# Completed 4943804 transitions in 11.135571644990705 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06066451198421419 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 1600.0 K   [31 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.511689841980115 s
# Calculation complete!
# Completed 4943804 transitions in 11.51240503496956 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06317106797359884 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 1800.0 K   [32 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.533040350070223 s
# Calculation complete!
# Completed 4943804 transitions in 12.533671391080134 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06226677494123578 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 2000.0 K   [33 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.352227110997774 s
# Calculation complete!
# Completed 4943804 transitions in 12.352865391992964 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.061510391999036074 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 2500.0 K   [34 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.971921829972416 s
# Calculation complete!
# Completed 4943804 transitions in 11.972597550950013 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06105892395135015 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 3000.0 K   [35 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.017181014991365 s
# Calculation complete!
# Completed 4943804 transitions in 13.017811865895055 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06187728594522923 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1e-05 bar, T = 3500.0 K   [36 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.372590866987593 s
# Calculation complete!
# Completed 4943804 transitions in 12.373224160983227 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06269356596749276 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 100.0 K   [37 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 3.675056569976732 s
# Calculation complete!
# Completed 4943804 transitions in 3.6756755630485713 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06536668608896434 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 200.0 K   [38 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.238167339935899 s
# Calculation complete!
# Completed 4943804 transitions in 5.238890685024671 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06408333498984575 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 300.0 K   [39 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.699861261993647 s
# Calculation complete!
# Completed 4943804 transitions in 5.700473804026842 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0642280459869653 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 400.0 K   [40 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.914890618994832 s
# Calculation complete!
# Completed 4943804 transitions in 6.9155400369782 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06426569703035057 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 500.0 K   [41 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.346343110082671 s
# Calculation complete!
# Completed 4943804 transitions in 7.346946545992978 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06123006506823003 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 600.0 K   [42 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.971791101968847 s
# Calculation complete!
# Completed 4943804 transitions in 7.972395166987553 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06574645300861448 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 700.0 K   [43 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.787697518011555 s
# Calculation complete!
# Completed 4943804 transitions in 8.78833848296199 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06417572998907417 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 800.0 K   [44 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.131116998032667 s
# Calculation complete!
# Completed 4943804 transitions in 9.13171178905759 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06432138197124004 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 900.0 K   [45 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.38847484998405 s
# Calculation complete!
# Completed 4943804 transitions in 10.389094456913881 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06500831700395793 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 1000.0 K   [46 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.987142505939119 s
# Calculation complete!
# Completed 4943804 transitions in 9.98773478192743 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06615099299233407 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 1200.0 K   [47 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.797089091967791 s
# Calculation complete!
# Completed 4943804 transitions in 10.797744794050232 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0653471879195422 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 1400.0 K   [48 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.45081394398585 s
# Calculation complete!
# Completed 4943804 transitions in 11.451488681021146 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06617024808656424 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 1600.0 K   [49 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.734626990975812 s
# Calculation complete!
# Completed 4943804 transitions in 11.735245048999786 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06387459998950362 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 1800.0 K   [50 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.966354028088972 s
# Calculation complete!
# Completed 4943804 transitions in 11.966967902029864 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06276316894218326 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 2000.0 K   [51 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.852718327078037 s
# Calculation complete!
# Completed 4943804 transitions in 11.853407619986683 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06612635403871536 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 2500.0 K   [52 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.190073290956207 s
# Calculation complete!
# Completed 4943804 transitions in 12.190696429926902 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06279235298279673 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 3000.0 K   [53 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.973097426001914 s
# Calculation complete!
# Completed 4943804 transitions in 11.973822036990896 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06552358309272677 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.0001 bar, T = 3500.0 K   [54 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.38822700502351 s
# Calculation complete!
# Completed 4943804 transitions in 12.388743839925155 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05591572099365294 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 100.0 K   [55 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 3.9569240319542587 s
# Calculation complete!
# Completed 4943804 transitions in 3.957650381955318 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.055111155030317605 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 200.0 K   [56 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.269476379035041 s
# Calculation complete!
# Completed 4943804 transitions in 5.270157929044217 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06033930100966245 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 300.0 K   [57 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.818823121022433 s
# Calculation complete!
# Completed 4943804 transitions in 5.819519798038527 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.060765763046219945 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 400.0 K   [58 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.445993967936374 s
# Calculation complete!
# Completed 4943804 transitions in 6.446681684930809 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.059341249987483025 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 500.0 K   [59 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.977541661937721 s
# Calculation complete!
# Completed 4943804 transitions in 6.978166656102985 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05791815195698291 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 600.0 K   [60 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.5150290169985965 s
# Calculation complete!
# Completed 4943804 transitions in 7.5156212790170684 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05912654101848602 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 700.0 K   [61 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.479657783987932 s
# Calculation complete!
# Completed 4943804 transitions in 8.480259987991303 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06516061502043158 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 800.0 K   [62 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.68655000103172 s
# Calculation complete!
# Completed 4943804 transitions in 9.687124467920512 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06061362195760012 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 900.0 K   [63 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.42249805398751 s
# Calculation complete!
# Completed 4943804 transitions in 9.423078908002935 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05693932098802179 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 1000.0 K   [64 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.830884199938737 s
# Calculation complete!
# Completed 4943804 transitions in 9.831562567967921 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06381303898524493 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 1200.0 K   [65 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.745441654929891 s
# Calculation complete!
# Completed 4943804 transitions in 11.746031486080028 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.062390560982748866 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 1400.0 K   [66 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.534899406018667 s
# Calculation complete!
# Completed 4943804 transitions in 11.535648802062497 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06365046394057572 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 1600.0 K   [67 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.487649735063314 s
# Calculation complete!
# Completed 4943804 transitions in 11.488303447025828 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06533457792829722 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 1800.0 K   [68 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.77519478497561 s
# Calculation complete!
# Completed 4943804 transitions in 11.775809204089455 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05983406095765531 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 2000.0 K   [69 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.18826624599751 s
# Calculation complete!
# Completed 4943804 transitions in 11.188979416969232 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06087967799976468 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 2500.0 K   [70 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.374092888901941 s
# Calculation complete!
# Completed 4943804 transitions in 11.374740698025562 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.060903924982994795 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 3000.0 K   [71 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.275328821036965 s
# Calculation complete!
# Completed 4943804 transitions in 12.27591157099232 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06077567802276462 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.001 bar, T = 3500.0 K   [72 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.26573995302897 s
# Calculation complete!
# Completed 4943804 transitions in 12.266336763976142 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.050385716021992266 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 100.0 K   [73 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 4.269859352963977 s
# Calculation complete!
# Completed 4943804 transitions in 4.270566263003275 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.052140868036076427 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 200.0 K   [74 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 5.356889949995093 s
# Calculation complete!
# Completed 4943804 transitions in 5.357471365015954 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0521674919873476 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 300.0 K   [75 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.072090163012035 s
# Calculation complete!
# Completed 4943804 transitions in 6.072766209021211 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.052804855979047716 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 400.0 K   [76 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 6.640345965977758 s
# Calculation complete!
# Completed 4943804 transitions in 6.641018618945964 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05179356597363949 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 500.0 K   [77 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.798051836900413 s
# Calculation complete!
# Completed 4943804 transitions in 7.798670974909328 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05906556500121951 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 600.0 K   [78 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.465017709997483 s
# Calculation complete!
# Completed 4943804 transitions in 8.465692523051985 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05799295590259135 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 700.0 K   [79 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.568582403939217 s
# Calculation complete!
# Completed 4943804 transitions in 8.569340165005997 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.057810807949863374 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 800.0 K   [80 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.99577831395436 s
# Calculation complete!
# Completed 4943804 transitions in 9.996483316994272 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05693138693459332 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 900.0 K   [81 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.673627187032253 s
# Calculation complete!
# Completed 4943804 transitions in 10.674242516048253 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.060852746944874525 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 1000.0 K   [82 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.881684824009426 s
# Calculation complete!
# Completed 4943804 transitions in 10.882348389015533 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06003738392610103 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 1200.0 K   [83 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.908855685032904 s
# Calculation complete!
# Completed 4943804 transitions in 10.90946629201062 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06073245406150818 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 1400.0 K   [84 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.447188174002804 s
# Calculation complete!
# Completed 4943804 transitions in 11.447917482000776 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05768239195458591 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 1600.0 K   [85 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.169946495909244 s
# Calculation complete!
# Completed 4943804 transitions in 11.170536836027168 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.06153996498323977 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 1800.0 K   [86 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.026819008984603 s
# Calculation complete!
# Completed 4943804 transitions in 12.027432435075752 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.059180422918871045 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 2000.0 K   [87 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.654819431016222 s
# Calculation complete!
# Completed 4943804 transitions in 11.655473422957584 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05459228600375354 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 2500.0 K   [88 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.62940306100063 s
# Calculation complete!
# Completed 4943804 transitions in 12.630133985891007 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05521048104856163 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 3000.0 K   [89 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.324320994899608 s
# Calculation complete!
# Completed 4943804 transitions in 12.324987725005485 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05780639499425888 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.01 bar, T = 3500.0 K   [90 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.044193080044352 s
# Calculation complete!
# Completed 4943804 transitions in 12.044761923025362 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.046587196993641555 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 100.0 K   [91 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 7.359618829097599 s
# Calculation complete!
# Completed 4943804 transitions in 7.360247111064382 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.049179687979631126 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 200.0 K   [92 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.276076063979417 s
# Calculation complete!
# Completed 4943804 transitions in 8.276652458007447 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04864792595617473 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 300.0 K   [93 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.01480806991458 s
# Calculation complete!
# Completed 4943804 transitions in 8.015452399966307 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04993132397066802 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 400.0 K   [94 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.916195441968739 s
# Calculation complete!
# Completed 4943804 transitions in 8.916832332033664 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.047853979049250484 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 500.0 K   [95 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 8.602752964012325 s
# Calculation complete!
# Completed 4943804 transitions in 8.603370669065043 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04744969098828733 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 600.0 K   [96 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.548304625088349 s
# Calculation complete!
# Completed 4943804 transitions in 9.548929719021544 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05037547892425209 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 700.0 K   [97 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 9.362110774964094 s
# Calculation complete!
# Completed 4943804 transitions in 9.362717574927956 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.050102135981433094 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 800.0 K   [98 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.03374874102883 s
# Calculation complete!
# Completed 4943804 transitions in 11.03431489795912 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05357121303677559 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 900.0 K   [99 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 10.795155600993894 s
# Calculation complete!
# Completed 4943804 transitions in 10.795823533087969 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05002584704197943 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 1000.0 K   [100 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.580661047017202 s
# Calculation complete!
# Completed 4943804 transitions in 11.581398242968135 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.049508110038004816 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 1200.0 K   [101 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.009871895075776 s
# Calculation complete!
# Completed 4943804 transitions in 12.01055632904172 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05855776998214424 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 1400.0 K   [102 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.938625134062022 s
# Calculation complete!
# Completed 4943804 transitions in 11.939270606031641 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05321435199584812 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 1600.0 K   [103 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.385881120921113 s
# Calculation complete!
# Completed 4943804 transitions in 11.386488136020489 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05408916703891009 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 1800.0 K   [104 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.866504936944693 s
# Calculation complete!
# Completed 4943804 transitions in 11.867235946003348 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05010591296013445 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 2000.0 K   [105 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.89172568905633 s
# Calculation complete!
# Completed 4943804 transitions in 11.892328909016214 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05535272497218102 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 2500.0 K   [106 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.516613461077213 s
# Calculation complete!
# Completed 4943804 transitions in 11.517216901062056 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.055529113044030964 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 3000.0 K   [107 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.17140025808476 s
# Calculation complete!
# Completed 4943804 transitions in 12.172044394072145 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.058075026026926935 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 0.1 bar, T = 3500.0 K   [108 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.260725968983024 s
# Calculation complete!
# Completed 4943804 transitions in 12.261335304006934 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04393018502742052 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 100.0 K   [109 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.157720676041208 s
# Calculation complete!
# Completed 4943804 transitions in 13.15832692105323 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04352094198111445 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 200.0 K   [110 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.524868199951015 s
# Calculation complete!
# Completed 4943804 transitions in 12.525565969990566 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04531442606821656 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 300.0 K   [111 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.696664532995783 s
# Calculation complete!
# Completed 4943804 transitions in 12.697252875077538 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04432681400794536 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 400.0 K   [112 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.849789776955731 s
# Calculation complete!
# Completed 4943804 transitions in 12.850602071965113 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04439964098855853 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 500.0 K   [113 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.72906709893141 s
# Calculation complete!
# Completed 4943804 transitions in 12.729716774076223 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04437146196141839 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 600.0 K   [114 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.213296298054047 s
# Calculation complete!
# Completed 4943804 transitions in 13.214013812015764 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.045636437949724495 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 700.0 K   [115 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.060639506904408 s
# Calculation complete!
# Completed 4943804 transitions in 13.061288160970435 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04486118198838085 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 800.0 K   [116 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.968798403046094 s
# Calculation complete!
# Completed 4943804 transitions in 12.969415587023832 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.046429223963059485 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 900.0 K   [117 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.309267107979394 s
# Calculation complete!
# Completed 4943804 transitions in 13.309826261946 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05082865501753986 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 1000.0 K   [118 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.116510932100937 s
# Calculation complete!
# Completed 4943804 transitions in 12.117160986061208 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05168491997756064 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 1200.0 K   [119 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.86826255498454 s
# Calculation complete!
# Completed 4943804 transitions in 12.868882603012025 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04746168898418546 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 1400.0 K   [120 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.130057147005573 s
# Calculation complete!
# Completed 4943804 transitions in 13.130686745978892 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04657363798469305 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 1600.0 K   [121 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.217921543982811 s
# Calculation complete!
# Completed 4943804 transitions in 12.218591058044694 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04639595502521843 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 1800.0 K   [122 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.100523094995879 s
# Calculation complete!
# Completed 4943804 transitions in 12.101265353965573 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.046090197982266545 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 2000.0 K   [123 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.067528257030062 s
# Calculation complete!
# Completed 4943804 transitions in 13.068164758034982 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.05179126700386405 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 2500.0 K   [124 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.0154198249802 s
# Calculation complete!
# Completed 4943804 transitions in 13.016078216955066 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.046302962000481784 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 3000.0 K   [125 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.78283730999101 s
# Calculation complete!
# Completed 4943804 transitions in 12.783366293995641 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04784910602029413 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 1.0 bar, T = 3500.0 K   [126 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.138677758048289 s
# Calculation complete!
# Completed 4943804 transitions in 12.139233086956665 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.042419950012117624 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 100.0 K   [127 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.806801366969012 s
# Calculation complete!
# Completed 4943804 transitions in 12.80751585692633 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04587377095595002 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 200.0 K   [128 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.14169244398363 s
# Calculation complete!
# Completed 4943804 transitions in 13.142298428923823 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04377426207065582 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 300.0 K   [129 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.096228218986653 s
# Calculation complete!
# Completed 4943804 transitions in 13.09687476104591 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04784317500889301 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 400.0 K   [130 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.043388839927502 s
# Calculation complete!
# Completed 4943804 transitions in 13.044042347115465 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04977381299249828 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 500.0 K   [131 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.781767855980434 s
# Calculation complete!
# Completed 4943804 transitions in 12.782507373951375 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04841430205851793 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 600.0 K   [132 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.869223056011833 s
# Calculation complete!
# Completed 4943804 transitions in 12.869871187023818 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.048198148026131094 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 700.0 K   [133 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.70571512391325 s
# Calculation complete!
# Completed 4943804 transitions in 12.706314121023752 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.048712681978940964 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 800.0 K   [134 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.22335606708657 s
# Calculation complete!
# Completed 4943804 transitions in 13.224021645030007 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.044262447976507246 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 900.0 K   [135 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.437525157933123 s
# Calculation complete!
# Completed 4943804 transitions in 12.438160351011902 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04903089802246541 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 1000.0 K   [136 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.028822838910855 s
# Calculation complete!
# Completed 4943804 transitions in 13.02944823296275 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04977445199619979 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 1200.0 K   [137 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.546998989069834 s
# Calculation complete!
# Completed 4943804 transitions in 12.547632861067541 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04942053300328553 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 1400.0 K   [138 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 11.77701087098103 s
# Calculation complete!
# Completed 4943804 transitions in 11.777807811973616 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04584099689964205 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 1600.0 K   [139 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.859460031031631 s
# Calculation complete!
# Completed 4943804 transitions in 12.860072325100191 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.045678650960326195 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 1800.0 K   [140 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.712787160999142 s
# Calculation complete!
# Completed 4943804 transitions in 12.713450161041692 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04557379905600101 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 2000.0 K   [141 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.501946018077433 s
# Calculation complete!
# Completed 4943804 transitions in 12.502525715972297 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.045154371997341514 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 2500.0 K   [142 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.038636273005977 s
# Calculation complete!
# Completed 4943804 transitions in 12.03930924704764 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.046416557976044714 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 3000.0 K   [143 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.052009608014487 s
# Calculation complete!
# Completed 4943804 transitions in 13.052748923073523 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04682814597617835 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 10.0 bar, T = 3500.0 K   [144 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.482248733052984 s
# Calculation complete!
# Completed 4943804 transitions in 12.482897090027109 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0414850739762187 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 100.0 K   [145 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.058768524904735 s
# Calculation complete!
# Completed 4943804 transitions in 13.059351052041166 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04297949094325304 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 200.0 K   [146 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.544380956096575 s
# Calculation complete!
# Completed 4943804 transitions in 12.54505735298153 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04222539404872805 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 300.0 K   [147 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.523752348031849 s
# Calculation complete!
# Completed 4943804 transitions in 12.524374535074458 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04333206999581307 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 400.0 K   [148 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.74085711198859 s
# Calculation complete!
# Completed 4943804 transitions in 13.741477771080099 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.043237288016825914 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 500.0 K   [149 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.178764269920066 s
# Calculation complete!
# Completed 4943804 transitions in 13.179388087941334 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04354859399609268 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 600.0 K   [150 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.702848513959907 s
# Calculation complete!
# Completed 4943804 transitions in 12.703517176909372 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.042927110102027655 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 700.0 K   [151 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.490916351904161 s
# Calculation complete!
# Completed 4943804 transitions in 12.491519924020395 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.043079708935692906 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 800.0 K   [152 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.622562621952966 s
# Calculation complete!
# Completed 4943804 transitions in 12.623154980014078 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04418213805183768 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 900.0 K   [153 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.50852125196252 s
# Calculation complete!
# Completed 4943804 transitions in 12.50911395600997 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04483901394996792 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 1000.0 K   [154 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.608269380987622 s
# Calculation complete!
# Completed 4943804 transitions in 12.608919562073424 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.044548472040332854 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 1200.0 K   [155 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.48697097308468 s
# Calculation complete!
# Completed 4943804 transitions in 12.487528759986162 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.043774510035291314 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 1400.0 K   [156 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.446121397078969 s
# Calculation complete!
# Completed 4943804 transitions in 12.44673280895222 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.0442595420172438 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 1600.0 K   [157 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 13.081081763026305 s
# Calculation complete!
# Completed 4943804 transitions in 13.081629239954054 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04393599706236273 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 1800.0 K   [158 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.515236168983392 s
# Calculation complete!
# Completed 4943804 transitions in 12.515831414959393 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.04423645604401827 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 2000.0 K   [159 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.514060385059565 s
# Calculation complete!
# Completed 4943804 transitions in 12.514662691974081 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.044609796022996306 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 2500.0 K   [160 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.50134292000439 s
# Calculation complete!
# Completed 4943804 transitions in 12.501966802985407 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.044294613995589316 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 3000.0 K   [161 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.751555955037475 s
# Calculation complete!
# Completed 4943804 transitions in 12.752126144012436 s
#
# Pre-computing Voigt profiles...
# Voigt profiles computed in 0.045155980973504484 s
# Pre-computation steps complete
# Generating cross section for AlO at P = 100.0 bar, T = 3500.0 K   [162 of 162]
# Computing transitions from ATP.h5 | 0.0% complete
# Completed 4943804 transitions in 12.560396407963708 s
# Calculation complete!
# Completed 4943804 transitions in 12.56103864510078 s
#
# Total runtime: 2098.7168893159833 s

# %% [markdown]
# ## Plot Computed Cross Section

# %% [markdown]
# We'll now plot two temperatures and pressures to show the T and P dependences of AlO's cross section.

# %%
from Excalibur.misc import read_cross_section_file, cross_section_collection
from Excalibur.plot import plot_cross_section

'''Read in the cross section we just computed'''

# Read in cross section at 1000 K
nu, sigma = read_cross_section_file(species = species, database = database, 
                                    filename = species + '_T1000.0K_log_P0.0_' + broadening + '_sigma.txt')

# Read in cross section at 2000 K
nu2, sigma2 = read_cross_section_file(species = species, database = database,
                                        filename = species + '_T2000.0K_log_P0.0_' + broadening + '_sigma.txt')

'''Add both cross sections to collection in preparation for plotting'''

cross_sections = []

# Add first cross section to collection
cross_sections = cross_section_collection(new_x = nu, new_y = sigma, collection = cross_sections)

# Add second cross section to collection, making sure to specify the previous collection as a parameter
cross_sections = cross_section_collection(new_x = nu2, new_y = sigma2, collection = cross_sections)

plot_cross_section(collection = cross_sections, labels = [species + ' (1000 K, 1 bar)', species + ' (2000 K, 1 bar)'], 
                    filename = species + '_Temperature', y_min = 1.0e-30)


# Read in cross section at 1 mbar
nu, sigma = read_cross_section_file(species = species, database = database, 
                                    filename = species + '_T1000.0K_log_P-3.0_' + broadening + '_sigma.txt')

# Read in cross section at 10 bar
nu2, sigma2 = read_cross_section_file(species = species, database = database,
                                        filename = species + '_T1000.0K_log_P1.0_' + broadening + '_sigma.txt')

cross_sections = []

# Add first cross section to collection
cross_sections = cross_section_collection(new_x = nu, new_y = sigma, collection = cross_sections)

# Add second cross section to collection, making sure to specify the previous collection as a parameter
cross_sections = cross_section_collection(new_x = nu2, new_y = sigma2, collection = cross_sections)

plot_cross_section(collection = cross_sections, labels = [species + ' (1000 K, 1 mbar)', species + ' (1000 K, 10 bar)'], 
                    filename = species + '_Pressure', y_min = 1.0e-30)
# Out:
# Plotting complete.
#
# Plotting complete.

# %% [markdown]
# ### Package the cross section grid as a HDF5 file

# %% [markdown]
# By default, Excalibur writes the cross section for each (P,T) pair as a txt file in the /output folder.
#
# We'll now combine all of the different (P,T) pairs into a single HDF5 file for storage efficiency and fast read time.

# %%
from Excalibur.hdf5_package import make_single_species_HDF5

P = [1.0e-6, 1.0e-5, 1.0e-4, 1.0e-3, 1.0e-2, 1.0e-1, 1.0e0, 1.0e1, 1.0e2]    # Pressure (bar)
log_P = [-6.0, -5.0, -4.0, -3.0, -2.0, -1.0, 0.0, 1.0, 2.0]                  # log10 pressure
T = [100.0, 200.0, 300.0, 400.0, 500.0, 600.0, 700.0, 800.0,                 # Temperature (K)
     900.0, 1000.0, 1200.0, 1400.0, 1600.0, 1800.0, 2000.0,
     2500.0, 3000.0, 3500.0]

make_single_species_HDF5(species, database = database, linelist = linelist, 
                         log_P = log_P, T = T, isotope = 'default', 
                         broadening = broadening, output_dir = './output/HDF5/')
# Out:
# Now preparing HDF5 file for: AlO
# Progress: 100%|██████████| 162/162 [06:39<00:00,  2.46s/it]
# AlO done

# %% [markdown]
# #### Combining different chemical species into an opacity database

# %% [markdown]
# Once you have made the HDF5 file for a single chemical species, you can combined them into an opacity database HDF5 file containing the cross sections for multiple gases.

# %%
from Excalibur.hdf5_package import extend_HDF5_database

database_name = 'Combined_Opacity_database.hdf5'   # If this database doesn't already exist, Excalibur will create the file

extend_HDF5_database(database_name, species)
# Out:
# AlO done

# %% [markdown]
# Let's print the attributes of our new opacity database.

# %%
import h5py

def print_attrs(name, obj):
    """Print attributes of an HDF5 object."""
    print(name)
    for key, val in obj.attrs.items():
        print(f"  {key}: {val}")

def list_all_attributes(filename):
    """List all attributes in an HDF5 file."""
    with h5py.File(filename, 'r') as f:
        f.visititems(print_attrs)

list_all_attributes('./Combined_Opacity_database.hdf5')
# Out:
# AlO
#   Broadening: H2-He
#   Linelist: ATP
#   Modified: 2024-05-10
#   Source: ExoMol
#   Version: v2
# AlO/T
#   Units: K
#   Variable: Temperature
# AlO/log(P)
#   Units: log10(P/bar)
#   Variable: Pressure (log10 scale)
# AlO/log(sigma)
#   Units: log10(sigma/m^2)
#   Variable: Cross section (log10 scale)
# AlO/nu
#   Units: cm^-1
#   Variable: Wavenumber

# %% [markdown]
# Congratulations, you've made your fitst opacity database! 🎉
#
# You can now use this HDF5 file with your favourite exoplanet or brown dwarf modelling code.
